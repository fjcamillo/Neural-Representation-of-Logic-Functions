# %% [markdown]
# # Logic Functions or Logic Gates Represented using a Perceptron

# %%
import numpy as np

# %%
w = np.array([1,2,3])
x = np.array([4,5,6])
b = 1

# %%
w
# Out:
# array([1, 2, 3])

# %%
w.transpose().dot(x)
# Out:
# 32
